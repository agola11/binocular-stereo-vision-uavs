# %% [markdown]
# # SVM Ball Tracking Test

# %% [markdown]
# ## Imports

# %%
"""
Author: Ankush Gola
"""

import numpy as np
import scipy as sp
from sklearn import preprocessing
from sklearn import svm
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import time
import cv2

# Configure matplotlib to show figures embedded in the notebook
# %matplotlib inline

# %% [markdown]
# ## Training

# %%
def flatten(img):
    """
    Flatten a color image into a vector of pixels
    """
    M, N, P = img.shape
    return img.reshape(M*N, P)

    #['train_1_sunny', 'train_2_sunny', 'train_3_sunny', 'train_4_sunny', 'train_1_cloudy', 'train_2_cloudy', 
    #'train_3_cloudy', 'train_5_cloudy', 'train_6_cloudy', 'train_7_cloudy', 'train_8_cloudy',

# %%
imgs = ['ball_1', 'ball_2', 'ball_3', 'ball_5']

d = {}

# Flatten images into a single vector
for img in imgs:
    train = (mpimg.imread(img+'.jpg').astype(float))/255
    train = flatten(train)
    d[img] = train
    
X = np.vstack(tuple([d[k] for k in d]))

# Preprocess data
#X = preprocessing.scale(X)

# Train Single Class SVM
nu = 1
gamma = 1
clf = svm.OneClassSVM(nu=1, kernel="rbf", gamma=1).fit(X)

# %%
# classify pixels in test_img
test_1 = (mpimg.imread('cloudy_test_1_img.jpg').astype(float))/255

M, N, P = test_1.shape
#test_1_f = preprocessing.scale(flatten(test_1), axis=1)
test_1_f = flatten(test_1)
Z = clf.predict(test_1_f)
Z = Z.reshape(M, N)

# mask the image
grey = [0.7, 0.7, 0.8]
out = np.copy(test_1)
out[np.where(Z==1)] = grey

plt.figure(1)
plt.title("Result", fontsize=14)
plt.imshow(out)
plt.show()

# %%
grey = [0.7, 0.7, 0.8]
out = np.copy(test_1)
out[np.where(Z==-1)] = grey

plt.figure(1)
plt.title("Result", fontsize=14)
plt.imshow(out)
plt.show()

# %%
print X.shape
# Out:
# (24394, 3)

# %% [markdown]
# ## Trying with a 2 class Classifier

# %%
ball_imgs = ['ball_1', 'ball_2', 'ball_3', 'ball_4', 'ball_5', 'ball_6']
back_imgs = ['sky_1', 'sky_2', 'sky_3', 'granite', 'joseph', 'skin', 'stone', 'sculpt', 'jacket', 'brick']

ball, back = {}, {}

# Flatten images into a single vector
for img in ball_imgs:
    train = (mpimg.imread('train/'+img+'.png').astype(float))/255
    ball[img] = train

for img in back_imgs:
    train = (mpimg.imread('train/'+img+'.png').astype(float))/255
    print train.shape
    back[img] = train

print train

X_ball, X_back = np.vstack(tuple([ball[k] for k in ball])), np.vstack(tuple([back[k] for k in back]))
y_ball, y_back = np.ones(X_ball.shape[0]).astype(np.uint8), np.zeros(X_back.shape[0]).astype(np.uint8)

X = np.vstack((X_ball, X_back))
y = np.hstack((y_ball, y_back))

# Train the SVM
C = 20
gamma = 1
clf2 = svm.SVC(C=C, kernel='rbf', gamma=gamma, cache_size=1500).fit(X, y)
# Out:
# (459, 3, 4)
# (280, 3, 4)
# (736, 3, 4)
# (374, 3, 4)
# (1221, 3, 4)
# (704, 3, 4)
# (910, 3, 4)
# (192, 3, 4)
# (629, 3, 4)
# (252, 3, 4)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-189-ba91508dff97> in <module>()
#      23 C = 20
#      24 gamma = 1
# ---> 25 clf2 = svm.SVC(C=C, kernel='rbf', gamma=gamma, cache_size=1500).fit(X, y)
#
# /Library/Python/2.7/site-packages/sklearn/svm/base.pyc in fit(self, X, y, sample_weight)
#     137         self._sparse = sparse and not callable(self.kernel)
#     138
# --> 139         X = check_array(X, accept_sparse='csr', dtype=np.float64, order='C')
#     140         y = self._validate_targets(y)
#     141
#
# /Library/Python/2.7/site-packages/sklearn/utils/validation.pyc in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features)
#     348         if not allow_nd and array.ndim >= 3:
#     349             raise ValueError("Found array with dim %d. Expected <= 2" %
# --> 350                              array.ndim)
#     351         if force_all_finite:
#     352             _assert_all_finite(array)
#
# ValueError: Found array with dim 3. Expected <= 2

# %%
for k in ball:
    mpimg.imsave(k, ball[k])

for k in back:
    mpimg.imsave(k, back[k])

# %% [markdown]
# ## Trying with a 3 class Classifier

# %%
ball_imgs = ['ball_1', 'ball_2', 'ball_3', 'ball_4', 'ball_5']
sky_imgs = ['sky_1', 'sky_2', 'sky_3'] 
other_imgs = ['joseph', 'stone', 'granite', 'skin']

ball, sky, other = {}, {}, {}

# Flatten images into a single vector
for img in ball_imgs:
    ball_img = (mpimg.imread('train/'+img+'.jpg').astype(float))/255
    train = flatten(ball_img)
    ball[img] = train

for img in sky_imgs:
    sky_img = (mpimg.imread('train/'+img+'.jpg').astype(float))/255
    train = flatten(sky_img)
    sky[img] = train

for img in other_imgs:
    other_img = (mpimg.imread('train/'+img+'.jpg').astype(float))/255
    train = flatten(other_img)
    other[img] = train


X_ball, X_sky, X_other = np.vstack(tuple([ball[k] for k in ball])), np.vstack(tuple([sky[k] for k in sky])), np.vstack(tuple([other[k] for k in other]))

o = np.empty(X_other.shape[0])
o.fill(2)

print o.shape
y_ball, y_sky, y_other = np.zeros(X_ball.shape[0]), np.ones(X_sky.shape[0]), o

X = np.vstack((X_ball, X_sky, X_other))
y = np.hstack((y_ball, y_sky, y_other))
#X = preprocessing.scale(X)

print X.shape

# Train the SVM
C = 2
gamma = 1
clf3 = svm.SVC(C=C, kernel='linear', gamma=gamma).fit(X, y)
# Out:
# (3209,)
# (7199, 3)

# %% [markdown]
# ## Classify

# %%
test_1 = ((mpimg.imread('test/indoor_test_2_img.jpg')).astype(float))/255
test_1 = cv2.resize(test_1,None,fx=0.5, fy=0.5)

M, N, P = test_1.shape
#test_1_f = preprocessing.scale(flatten(test_1), axis=1)
test_1_f = flatten(test_1)

# classify pixels in test_1
t = time.time()
Z = clf2.predict(test_1_f)
Z = Z.reshape(M, N)
print time.time()-t

# mask the image
grey = [0.7, 0.7, 0.8]
out = np.copy(test_1)
out[np.where(Z==0)] = grey

plt.figure()
plt.imshow(out)

plt.figure()
plt.imshow(Z)
Z = cv2.GaussianBlur(Z.astype(np.float),(5,5),0)
Z = (Z*255).astype(np.uint8)
plt.figure()
plt.imshow(Z)



circles = cv2.HoughCircles(Z,cv2.cv.CV_HOUGH_GRADIENT,1,1600, param1 = 50, param2 = 10, minRadius = 5)
if circles != None:
    (x, y, r) = circles[0,:][0]
    print (x, y, r)
    cv2.circle(Z, (x, y), r, (0,255,0), 2)
    cv2.circle(Z,(x, y), 3 ,(0,0,255),3)
# Out:
# 1.4700949192
# (133.5, 131.5, 11.067972)
